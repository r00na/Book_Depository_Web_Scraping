# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
url = 'https://www.bookdepository.com/category/2626/Science-Fiction'

# %%
client = requests.get(url)

# %%
html = client.text
html
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n\n    <link rel="preconnect" href="https://d3ogvdx946i4sr.cloudfront.net"/>\n<link rel="dns-prefetch" href="https://d3ogvdx946i4sr.cloudfront.net"/>\n<script type="text/javascript">\n        function csmWidgetStart(widgetName) {\n            if (typeof uet == \'function\') {\n                uet(\'bb\', widgetName, {wb: 1});\n            }\n        }\n        function csmWidgetEnd(widgetName) {\n            if (typeof uet == \'function\') {\n                uex(\'ld\', widgetName, {wb: 1});\n            }\n        }\n    </script>\n    <noscript>\n        <style>\n            .hide-when-no-js {\n                display: none !important;\n            }\n\n            .show-when-no-js {\n                display: block !important;\n            }\n        </style>\n    </noscript>\n\n    \n<script type=\'text/javascript\'>var ue_t0=ue_t0||+new Date();</script>\n<script type=\'text/javascript\'>\nwindow.ue_ihb = (window.ue_ihb || window.ueinit |
# ...

# %%
client.close()

# %%
soup = bs(html, "html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <link href="https://d3ogvdx946i4sr.cloudfront.net" rel="preconnect"/>
# <link href="https://d3ogvdx946i4sr.cloudfront.net" rel="dns-prefetch"/>
# <script type="text/javascript">
#         function csmWidgetStart(widgetName) {
#             if (typeof uet == 'function') {
#                 uet('bb', widgetName, {wb: 1});
#             }
#         }
#         function csmWidgetEnd(widgetName) {
#             if (typeof uet == 'function') {
#                 uex('ld', widgetName, {wb: 1});
#             }
#         }
#     </script>
# <noscript>
# <style>
#             .hide-when-no-js {
#                 display: none !important;
#             }
#
#             .show-when-no-js {
#                 display: block !important;
#             }
#         </style>
# </noscript>
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# ...

# %%
contain = soup.find_all("div" ,{"class" , "book-item"})

# %%
len(contain)
# Out:
# 171

# %%
name = contain[0].find_all("h3" , {"class" : "title"})
book_name = name[0].text.strip()

# %%
name = soup.find_all("h3", {"class" : "title"})
name[0].text.strip()
# Out:
# 'They'

# %%
price = soup.find_all("p", {"class" : "price"})
price[0].text.strip()
# Out:
# 'US$12.11'

# %%
author = soup.find_all("p", {"class" : "author"})
author[0].text.strip()
# Out:
# 'Kay Dick'

# %%
import csv   
name0=[]
price0=[]
author0=[]

for x in contain:
    name = x.find_all("h3" , {"class":"title"})
    book_name = name[0].text.strip()
    
      
    price = x.find_all("p",{"class":"price"})
    price_us = price[0].text.strip()
    
    author = x.find_all("p",{"class":"author"})
    Author = author[0].text.strip()
    
  
    name0.append(book_name)
    author0.append(Author)
    price0.append(price_us)
    rating0.append(Rating)
    

book_dic = {"name":name0,"author":author0,"price":price0}
deff = pd.DataFrame(book_dic)
deff.to_csv("datafile.csv")

# %%
for i in contain:
    name = i.find_all("h3",{"class":"title"})
    book_name = name[0].text.strip()
    
    price = i.find_all("p",{"class":"price"})
    price_us = price[0].text.strip()
    
    author = i.find_all("p",{"class":"author"})
    Author = author[0].text.strip()
   
    rating = i.find_all("div",class_ = "stars")
    rate=[]
    str1 = i
    str2 = " "
    
    for x in range(0 , len(rating)):
        for i in rating :
            countf = 0
            counth = 0
            for line in rating :
                print(i)
                if(str1 == 'star full-star'):
                    countf +=1
                elif(str2 == 'star half-star'):
                    counth +=1
        
    
    print("Book's name: ", book_name)
    print("Book's price: ",price_us)
    print("Book's author: ", Author)
    print("Book's rating:",rating,"\n\n")
# Out:
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# <span class="star"></span>
# </div>
# Book's name:  They
# Book's price:  US$12.11
# Book's author:  Kay Dick
# Book's rating: [<div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# <span class="star"></span>
# </div>]
#
#
# <div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# <span class="star half-star"></span>
# </div>
# Book's name:  The Galaxy, and the Ground Within
# Book's price:  US$12.48
# Book's author:  Becky Chambers
# Book's rating: [<div class="stars">
# <span class="star full-star"></span>
# <span class="star full-star"></span>
# ...

# %%
pd.read_csv('datafile.csv')
# Out:
#      Unnamed: 0                               name             author  \
# 0             0                               They           Kay Dick
# 1             1  The Galaxy, and the Ground Within     Becky Chambers
# 2             2         Notes from the Burning Age       Claire North
# 3             3       The One Impossible Labyrinth     Matthew Reilly
# 4             4          A Desolation Called Peace     Arkady Martine
# ..          ...                                ...                ...
# 166         166                 A Deadly Education        Naomi Novik
# 167         167             A Memory Called Empire     Arkady Martine
# 168         168            Mob Psycho 100 Volume 1                ONE
# 169         169          The Left Hand of Darkness  Ursula K. Le Guin
# 170         170                        Neuromancer     William Gibson
#
#                                                  price
# 0                                             US$12.11
# ...

# %%
data = pd.read_csv('datafile.csv')
plt.scatter(data['name'], data['price'])
plt.title("Scatter Plot")
plt.xlabel('name')
plt.ylabel('price')
plt.colorbar()
plt.show()

# %%
data = pd.read_csv('datafile.csv')
plt.scatter(data['author'], data['price'])
plt.title("Scatter Plot")
plt.xlabel('author')
plt.ylabel('price')
plt.colorbar()
plt.show()
